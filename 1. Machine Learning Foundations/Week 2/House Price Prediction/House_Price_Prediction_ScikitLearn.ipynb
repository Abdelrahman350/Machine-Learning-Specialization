# %% [markdown]
# # Import Scikit-Learn, Pandas and Numpy

# %%
import sklearn
import pandas as pd
import numpy as np

# %% [markdown]
# # 1. Read Data using Pandas

# %%
housing = pd.read_csv("data/home_data.csv")

# %%
housing
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900         3       1.00         1180
# 1      6414100192  20141209T000000  538000         3       2.25         2570
# 2      5631500400  20150225T000000  180000         2       1.00          770
# 3      2487200875  20141209T000000  604000         4       3.00         1960
# 4      1954400510  20150218T000000  510000         3       2.00         1680
# ...           ...              ...     ...       ...        ...          ...
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
# ...

# %% [markdown]
# # 2. Exploratory Data analysis

# %%
housing.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  int64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
housing.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
import matplotlib.pyplot as plt
housing.hist(bins=100, figsize=(20,15))
plt.show()

# %% [markdown]
# # 3. Data Preprocessing
# ## Train-Test split

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(housing, test_size=0.1, random_state=40)

# %%
fig = train_set.plot(kind="scatter", x='sqft_living', y='price', grid=True)

# %%
import seaborn as sns
def heat_map_plot(df):
    f, ax = plt.subplots(figsize=(32, 26))
    corr = df.corr()
    mp = sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
                     square=True, ax=ax, annot = True)
    mp.set_title(label='Dataset Correlation', fontsize=20)

# %%
import seaborn as sns

heat_map_plot(housing)

# %% [markdown]
# ## Selecting Features

# %%
numeric_all_features = ['id', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 
                        'waterfront', 'view', 'condition', 'grade', 'sqft_above', 'sqft_basement', 
                        'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15']

numeric_one_feature = ['sqft_living']

date_features = ['date']

label = ['price']

# %%
housing[numeric_one_feature].head()
# Out:
#    sqft_living
# 0         1180
# 1         2570
# 2          770
# 3         1960
# 4         1680

# %%
housing[numeric_all_features].head()
# Out:
#            id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  7129300520         3       1.00         1180      5650     1.0           0
# 1  6414100192         3       2.25         2570      7242     2.0           0
# 2  5631500400         2       1.00          770     10000     1.0           0
# 3  2487200875         4       3.00         1960      5000     1.0           0
# 4  1954400510         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
heat_map_plot(housing[numeric_all_features])

# %%
# Removing highly coorelated features
numeric_important_features = ['id', 'bedrooms', 'sqft_living', 'sqft_lot', 'floors', 
                              'waterfront', 'view', 'condition', 'sqft_basement', 
                              'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long']

# %%
heat_map_plot(housing[numeric_important_features])

# %% [markdown]
# # 4. Pipeline Data Processing

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression

def linear_regression_pipeline(feature):
    numerical_preprocessor = Pipeline([('num_standard', StandardScaler())])
    data_preprocessor_one = ColumnTransformer([('numerical_preprocessor', numerical_preprocessor, feature)])
    pipeline = Pipeline(steps=[('data_preprocessor', data_preprocessor_one),
                           ('Regression_Model', LinearRegression())])

    # Visualize the pipeline
    from sklearn import set_config
    set_config(display='diagram')
    
    return pipeline

# %% [markdown]
# ## One feature Pipeline

# %%
pipeline_one = linear_regression_pipeline(numeric_one_feature)
pipeline_one
# Out:
# Pipeline(steps=[('data_preprocessor',
#                  ColumnTransformer(transformers=[('numerical_preprocessor',
#                                                   Pipeline(steps=[('num_standard',
#                                                                    StandardScaler())]),
#                                                   ['sqft_living'])])),
#                 ('Regression_Model', LinearRegression())])

# %% [markdown]
# ## All features Pipeline

# %%
pipeline_all = linear_regression_pipeline(numeric_all_features)
pipeline_all
# Out:
# Pipeline(steps=[('data_preprocessor',
#                  ColumnTransformer(transformers=[('numerical_preprocessor',
#                                                   Pipeline(steps=[('num_standard',
#                                                                    StandardScaler())]),
#                                                   ['id', 'bedrooms',
#                                                    'bathrooms', 'sqft_living',
#                                                    'sqft_lot', 'floors',
#                                                    'waterfront', 'view',
#                                                    'condition', 'grade',
#                                                    'sqft_above',
#                                                    'sqft_basement', 'yr_built',
#                                                    'yr_renovated', 'zipcode',
#                                                    'lat', 'long',
# ...

# %% [markdown]
# ## Important features Pipeline

# %%
pipeline_important = linear_regression_pipeline(numeric_important_features)
pipeline_important
# Out:
# Pipeline(steps=[('data_preprocessor',
#                  ColumnTransformer(transformers=[('numerical_preprocessor',
#                                                   Pipeline(steps=[('num_standard',
#                                                                    StandardScaler())]),
#                                                   ['id', 'bedrooms',
#                                                    'sqft_living', 'sqft_lot',
#                                                    'floors', 'waterfront',
#                                                    'view', 'condition',
#                                                    'sqft_basement', 'yr_built',
#                                                    'yr_renovated', 'zipcode',
#                                                    'lat', 'long'])])),
#                 ('Regression_Model', LinearRegression())])

# %% [markdown]
# # 5. Models Training

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, mean_squared_error
from sklearn.metrics import mean_squared_error

def pipeline_prediction_plot(feature, label, pipeline):
    # Get train data to train the pipeline
    X_train = train_set[feature]
    y_train = train_set[label]
    
    pipeline.fit(X_train, y_train)
    
    # Use the fitted pipeline to make predictions on the train dataset
    train_predictions = pipeline.predict(X_train)
    
    # Get test data to test the pipeline
    X_test = test_set[feature]
    y_test = test_set[label]

    # Use the fitted pipeline to make predictions on the test dataset
    test_predictions = pipeline.predict(X_test)

    sns.regplot(x=y_train, y=train_predictions, scatter_kws={'alpha':1, 'color':'brown'})
    plt.xlabel('Actual Price')
    plt.ylabel('Predicted Price')
    plt.title("Training Set")
    plt.show()

    sns.regplot(x=y_test, y=test_predictions, scatter_kws={'alpha':1, 'color':'r'})
    plt.xlabel('Actual Price')
    plt.ylabel('Predicted Price')
    plt.title("Test Set")
    plt.show()
    
    plt.plot(test_set['sqft_living'], test_set['price'], '.',
             test_set['sqft_living'], pipeline.predict(X_test), '-')
    
    plt.xlabel('Sqft_living')
    plt.ylabel('Price')
    plt.title("Test Set")
    plt.show()
    
    housing_predictions = pipeline.predict(X_test)
    lin_rmse = mean_squared_error(y_test, housing_predictions, squared=False)
    print("Root Mean Square = ", lin_rmse)
    return(lin_rmse)

# %% [markdown]
# ## One feature model training

# %%
pipeline_prediction_plot(numeric_one_feature, label, pipeline_one)
# Out:
# Root Mean Square =  244236.66317320208
# 244236.66317320208

# %%
pipeline_prediction_plot(numeric_all_features, label, pipeline_all)
# Out:
# Root Mean Square =  187946.5055944691
# 187946.5055944691

# %% [markdown]
# ## Important features model training

# %%
pipeline_prediction_plot(numeric_important_features, label, pipeline_important)
# Out:
# Root Mean Square =  199654.8183927026
# 199654.8183927026

# %% [markdown]
# # 6. Apply learned models to make predictions

# %%
house_1 = housing[housing['id'] == 5309101200]
house_1
# Out:
#               id             date   price  bedrooms  bathrooms  sqft_living  \
# 1054  5309101200  20140605T000000  620000         4       2.25         2400
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 1054      5350     1.5           0     0  ...      7        1460
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat    long  \
# 1054            940      1929             0    98117  47.6763 -122.37
#
#       sqft_living15  sqft_lot15
# 1054           1250        4880
#
# [1 rows x 21 columns]

# %%
print(house_1['price'].values[0])
print(pipeline_one.predict(house_1[numeric_one_feature]))
print(pipeline_all.predict(house_1[numeric_all_features]))
print(pipeline_important.predict(house_1[numeric_important_features]))
# Out:
# 620000
# [[630593.40212151]]
# [[670828.37673004]]
# [[725327.9697838]]

# %%
house_2 = housing[housing['id']==1925069082]
house_2
# Out:
#               id             date    price  bedrooms  bathrooms  sqft_living  \
# 1361  1925069082  20150511T000000  2200000         5       4.25         4640
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 1361     22703     2.0           1     4  ...      8        2860
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 1361           1780      1952             0    98052  47.6393 -122.097
#
#       sqft_living15  sqft_lot15
# 1361           3140       14200
#
# [1 rows x 21 columns]

# %%
print(house_2['price'].values[0])
print(pipeline_one.predict(house_2[numeric_one_feature]))
print(pipeline_all.predict(house_2[numeric_all_features]))
print(pipeline_important.predict(house_2[numeric_important_features]))
# Out:
# 2200000
# [[1263335.52845344]]
# [[1974271.93087955]]
# [[2105800.80126281]]

# %% [markdown]
# # Assignment
# ## 1. Selection and summary statistics:
# ### Get average price per zipcode

# %%
averages = housing.groupby(['zipcode'], as_index=False)['price'].mean()
averages.head()
# Out:
#    zipcode         price
# 0    98001  2.808047e+05
# 1    98002  2.342840e+05
# 2    98003  2.941113e+05
# 3    98004  1.355927e+06
# 4    98005  8.101649e+05

# %% [markdown]
# ### Get the zipcode coerresponding to the maximum average prices

# %%
max_average_houses = averages[averages['price']==averages['price'].max()]
max_average_houses
# Out:
#     zipcode      price
# 24    98039  2160606.6

# %%
max_average_zipcode = int(max_average_houses.values[0][0])
max_average_zipcode
# Out:
# 98039

# %% [markdown]
# ## 2. Filtering Data

# %%
housing_filtered_sqft = housing[(housing['sqft_living'] > 2000) & (housing['sqft_living'] < 4000)]

# %%
print(housing_filtered_sqft.shape[0]/housing.shape[0])
# Out:
# 0.4215518437977143

# %% [markdown]
# ## 3. Building a Regression Model with More Features

# %%
my_features = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode']

advanced_features = [
'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode',
'condition', # condition of house
'grade', # measure of quality of construction
'waterfront', # waterfront property
'view', # type of view
'sqft_above', # square feet above ground
'sqft_basement', # square feet in basement
'yr_built', # the year built
'yr_renovated', # the year renovated
'lat', 'long', # the lat-long of the parcel
'sqft_living15', # average sq.ft. of 15 nearest neighbors
'sqft_lot15', # average lot size of 15 nearest neighbors
]

# %%
my_features_pipeline = linear_regression_pipeline(my_features)
my_features_pipeline
# Out:
# Pipeline(steps=[('data_preprocessor',
#                  ColumnTransformer(transformers=[('numerical_preprocessor',
#                                                   Pipeline(steps=[('num_standard',
#                                                                    StandardScaler())]),
#                                                   ['bedrooms', 'bathrooms',
#                                                    'sqft_living', 'sqft_lot',
#                                                    'floors', 'zipcode'])])),
#                 ('Regression_Model', LinearRegression())])

# %%
advanced_features_pipeline = linear_regression_pipeline(advanced_features)
advanced_features_pipeline
# Out:
# Pipeline(steps=[('data_preprocessor',
#                  ColumnTransformer(transformers=[('numerical_preprocessor',
#                                                   Pipeline(steps=[('num_standard',
#                                                                    StandardScaler())]),
#                                                   ['bedrooms', 'bathrooms',
#                                                    'sqft_living', 'sqft_lot',
#                                                    'floors', 'zipcode',
#                                                    'condition', 'grade',
#                                                    'waterfront', 'view',
#                                                    'sqft_above',
#                                                    'sqft_basement', 'yr_built',
#                                                    'yr_renovated', 'lat',
#                                                    'long', 'sqft_living15',
# ...

# %%
lin_rmse_my_features = pipeline_prediction_plot(my_features, label, my_features_pipeline)
# Out:
# Root Mean Square =  239022.1470676709

# %%
lin_rmse_advanced_features = pipeline_prediction_plot(advanced_features, label, advanced_features_pipeline)
# Out:
# Root Mean Square =  187980.28067340073

# %%
Difference = abs(lin_rmse_advanced_features - lin_rmse_my_features)
Difference
# Out:
# 51041.86639427018
